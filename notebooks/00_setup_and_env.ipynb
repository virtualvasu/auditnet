# %% [markdown]
# # 00 - Environment Setup and Verification
#
# This notebook sets up the complete environment for smart contract vulnerability detection using ML.
#
# **Goals:**
# - Install and import all required libraries
# - Verify GPU availability and compute environment
# - Set random seeds for reproducibility
# - Show project directory structure
# - Install and test Slither & Mythril
# - Save system information for reproducibility

# %% [markdown]
# ## 1. System Information and Environment

# %%
import sys
import os
import platform
from datetime import datetime
import subprocess

print("=" * 50)
print("SYSTEM INFORMATION")
print("=" * 50)
print(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Platform: {platform.platform()}")
print(f"Python Version: {sys.version}")
print(f"Working Directory: {os.getcwd()}")
print(f"Python Executable: {sys.executable}")
# Out:
# ==================================================
# SYSTEM INFORMATION
# ==================================================
# Date: 2025-11-10 22:48:34
# Platform: Linux-6.14.0-32-generic-x86_64-with-glibc2.39
# Python Version: 3.12.3 (main, Aug 14 2025, 17:47:21) [GCC 13.3.0]
# Working Directory: /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/notebooks
# Python Executable: /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/bin/python

# %% [markdown]
# ## 2. Install Required Packages

# %%
# Install core ML and data science packages
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers>=4.30.0
# !pip install tokenizers>=0.13.0
# !pip install scikit-learn>=1.3.0
# !pip install pandas>=2.0.0
# !pip install numpy>=1.24.0
# !pip install matplotlib>=3.7.0
# !pip install seaborn>=0.12.0
# !pip install plotly>=5.14.0
# !pip install datasets>=2.12.0
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (2.7.1+cu118)
# Requirement already satisfied: torchvision in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (0.22.1+cu118)
# Requirement already satisfied: torchaudio in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (2.7.1+cu118)
# Requirement already satisfied: filelock in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.3.1)
# Requirement already satisfied: filelock in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torch) (3.3.1)
# Requirement already satisfied: numpy in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torchvision) (2.3.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: numpy in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torchvision) (2.3.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from jinja2->torch) (2.0.1)
# zsh:1: 4.30.0 not found
# zsh:1: 4.30.0 not found
# zsh:1: 0.13.0 not found
# zsh:1: 0.13.0 not found
# zsh:1: 1.3.0 not found
# zsh:1: 1.3.0 not found
# zsh:1: 2.0.0 not found
# zsh:1: 2.0.0 not found
# zsh:1: 1.24.0 not found
# zsh:1: 1.24.0 not found
# zsh:1: 3.7.0 not found
# zsh:1: 3.7.0 not found
# zsh:1: 0.12.0 not found
# zsh:1: 0.12.0 not found
# zsh:1: 5.14.0 not found
# zsh:1: 5.14.0 not found
# zsh:1: 2.12.0 not found
# zsh:1: 2.12.0 not found

# %%
# Install additional tools for code analysis and visualization
# %pip install tree-sitter
# %pip install pygments
# %pip install tqdm
# %pip install wandb  # For experiment tracking (optional)
# %pip install ipywidgets  # For interactive visualizations (correct package name)
# Out:
# Requirement already satisfied: tree-sitter in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (0.25.2)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pygments in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (2.19.2)
# Requirement already satisfied: pygments in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (2.19.2)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: tqdm in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wandb in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (0.22.3)
# Requirement already satisfied: wandb in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (0.22.3)
# Requirement already satisfied: click>=8.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (6.33.0)
# Requirement already satisfied: pydantic<3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (2.12.4)
# Requirement already satisfied: pyyaml in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (2.43.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: click>=8.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (6.33.0)
# Requirement already satisfied: pydantic<3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (2.12.4)
# Requirement already satisfied: pyyaml in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (2.43.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: ipywidgets in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: decorator>=4.3.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install missing packages that might not have installed properly
# %pip install seaborn
# %pip install plotly
# %pip install datasets
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from seaborn) (2.3.4)
# Requirement already satisfied: pandas>=1.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from seaborn) (2.3.4)
# Requirement already satisfied: pandas>=1.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: six>=1.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly
# Collecting plotly
#   Using cached plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
#   Using cached plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from plotly) (25.0)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from plotly) (25.0)
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/9.9 MB ? eta -:--:--Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 6.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 6.2 MB/s eta 0:00:00m eta 0:00:01
# Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 3.6 MB/s eta 0:00:00m eta 0:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: narwhals, plotly
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.11.0 plotly-6.4.0
# Successfully installed narwhals-2.11.0 plotly-6.4.0
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Collecting datasets
# Collecting datasets
#   Using cached datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
#   Using cached datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (2.3.4)
# Requirement already satisfied: filelock in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (2.3.4)
# Collecting pyarrow>=21.0.0 (from datasets)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Using cached pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
#   Using cached pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (2.32.5)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (2.32.5)
# Collecting httpx<1.0.0 (from datasets)
# Collecting httpx<1.0.0 (from datasets)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tqdm>=4.66.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (4.67.1)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tqdm>=4.66.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
#   Using cached xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
# Collecting multiprocess<0.70.19 (from datasets)
#   Using cached multiprocess-0.70.18-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (6.0.3)
#   Using cached multiprocess-0.70.18-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Collecting anyio (from httpx<1.0.0->datasets)
# Collecting anyio (from httpx<1.0.0->datasets)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: certifi in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: certifi in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: six>=1.5 in /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting sniffio>=1.1 (from anyio->httpx<1.0.0->datasets)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1.0.0->datasets)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 4.1 MB/s eta 0:00:000:00:01m eta 0:00:015;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/511.6 kB ? eta -:--:--
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 4.1 MB/s eta 0:00:000:00:01
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading multiprocess-0.70.18-py312-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/150.3 kB ? eta -:--:--Downloading multiprocess-0.70.18-py312-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 870.2 kB/s eta 0:00:00MB/s eta 0:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 870.2 kB/s eta 0:00:00MB/s eta 0:00:01
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/47.7 MB 12.9 MB/s eta 0:00:04Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 6.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 6.1 MB/s eta 0:00:00
# Using cached xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: xxhash, sniffio, pyarrow, h11, dill, multiprocess, httpcore, anyio, httpx, datasets
# Successfully installed anyio-4.11.0 datasets-4.4.1 dill-0.4.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 multiprocess-0.70.18 pyarrow-22.0.0 sniffio-1.3.1 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 3. Import Libraries and Check Versions

# %%
# Core ML libraries
print("Importing PyTorch...")
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
print("✅ PyTorch imported successfully")

# Transformers for CodeBERT
print("Importing transformers...")
try:
    from transformers import (
        AutoTokenizer, 
        AutoModel, 
        AutoModelForSequenceClassification,
        TrainingArguments,
        Trainer
    )
    print("✅ Transformers imported successfully")
except ImportError as e:
    print(f"❌ Failed to import transformers: {e}")
    print("Installing transformers now...")
    import subprocess
    import sys
    subprocess.run([sys.executable, '-m', 'pip', 'install', 'transformers>=4.30.0'])
    # Try importing again
    from transformers import (
        AutoTokenizer, 
        AutoModel, 
        AutoModelForSequenceClassification,
        TrainingArguments,
        Trainer
    )
    print("✅ Transformers imported after installation")

# Data science libraries
print("Importing data science libraries...")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
print("✅ Data science libraries imported")

# ML utilities
print("Importing ML utilities...")
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report
)
print("✅ ML utilities imported")

# Utility libraries
print("Importing utility libraries...")
import json
import glob
import re
from pathlib import Path
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
print("✅ Utility libraries imported")

print("\n🎉 All libraries imported successfully!")
# Out:
# Importing PyTorch...
# ✅ PyTorch imported successfully
# Importing transformers...
# ✅ Transformers imported successfully
# Importing data science libraries...
# ✅ Data science libraries imported
# Importing ML utilities...
# ✅ ML utilities imported
# Importing utility libraries...
# ✅ Utility libraries imported
#
# 🎉 All libraries imported successfully!

# %%
# Debug: Check Python environment and installed packages
import sys
import subprocess

print("🔍 DEBUGGING ENVIRONMENT")
print("=" * 50)
print(f"Python executable: {sys.executable}")
print(f"Python path: {sys.path[:3]}...")  # Show first 3 paths

# Check if transformers is actually installed
try:
    result = subprocess.run([sys.executable, '-m', 'pip', 'list'], 
                          capture_output=True, text=True)
    if 'transformers' in result.stdout:
        print("✅ transformers found in pip list")
        # Get the exact version
        for line in result.stdout.split('\n'):
            if line.startswith('transformers'):
                print(f"   {line}")
    else:
        print("❌ transformers NOT found in pip list")
        print("Installing transformers directly...")
        subprocess.run([sys.executable, '-m', 'pip', 'install', 'transformers>=4.30.0'])
        print("✅ transformers installed")
except Exception as e:
    print(f"Error checking packages: {e}")

# Try importing transformers
try:
    import transformers
    print(f"✅ transformers imported successfully: {transformers.__version__}")
except ImportError as e:
    print(f"❌ Failed to import transformers: {e}")
    # Try installing again with specific method
    print("Attempting to install transformers...")
    subprocess.run([sys.executable, '-m', 'pip', 'install', '--upgrade', 'transformers'])
# Out:
# 🔍 DEBUGGING ENVIRONMENT
# ==================================================
# Python executable: /home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/venv/bin/python
# Python path: ['/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload']...
# ✅ transformers found in pip list
#    transformers             4.57.1
# ✅ transformers imported successfully: 4.57.1
# ✅ transformers found in pip list
#    transformers             4.57.1
# ✅ transformers imported successfully: 4.57.1

# %%
# Check versions of critical packages
import sklearn
import transformers
import matplotlib

print("=" * 50)
print("PACKAGE VERSIONS")
print("=" * 50)
print(f"PyTorch: {torch.__version__}")
print(f"Transformers: {transformers.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Seaborn: {sns.__version__}")
# Out:
# ==================================================
# PACKAGE VERSIONS
# ==================================================
# PyTorch: 2.7.1+cu118
# Transformers: 4.57.1
# Pandas: 2.3.3
# NumPy: 2.3.4
# Scikit-learn: 1.7.2
# Matplotlib: 3.10.6
# Seaborn: 0.13.2

# %% [markdown]
# ## 4. GPU and Compute Environment Check

# %%
print("=" * 50)
print("COMPUTE ENVIRONMENT")
print("=" * 50)

# Check CUDA availability
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Version: {torch.version.cuda}")
    print(f"GPU Count: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"  Memory: {torch.cuda.get_device_properties(i).total_memory / 1e9:.1f} GB")
    
    # Set default device
    device = torch.device("cuda")
    print(f"\n🚀 Using GPU: {torch.cuda.get_device_name()}")
else:
    device = torch.device("cpu")
    print("⚠️  Using CPU (GPU not available)")

print(f"\nDefault Device: {device}")
# Out:
# ==================================================
# COMPUTE ENVIRONMENT
# ==================================================
# CUDA Available: False
# ⚠️  Using CPU (GPU not available)
#
# Default Device: cpu

# %% [markdown]
# ## 5. Set Random Seeds for Reproducibility

# %%
import random

# Set random seeds
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

print(f"✅ Random seeds set to {SEED} for reproducibility")

# Set matplotlib style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("✅ Plotting style configured")
# Out:
# ✅ Random seeds set to 42 for reproducibility
# ✅ Plotting style configured

# %% [markdown]
# ## 6. Project Directory Structure

# %%
# Display project structure
def show_directory_tree(path, prefix="", max_depth=3, current_depth=0):
    """Display directory tree structure"""
    if current_depth >= max_depth:
        return
    
    path = Path(path)
    items = sorted(path.iterdir(), key=lambda x: (x.is_file(), x.name))
    
    for i, item in enumerate(items):
        is_last = i == len(items) - 1
        current_prefix = "└── " if is_last else "├── "
        print(f"{prefix}{current_prefix}{item.name}")
        
        if item.is_dir() and not item.name.startswith('.') and current_depth < max_depth - 1:
            extension = "    " if is_last else "│   "
            show_directory_tree(item, prefix + extension, max_depth, current_depth + 1)

print("=" * 50)
print("PROJECT DIRECTORY STRUCTURE")
print("=" * 50)
show_directory_tree(".", max_depth=4)
# Out:
# ==================================================
# PROJECT DIRECTORY STRUCTURE
# ==================================================
# └── 00_setup_and_env.ipynb

# %%
# Create necessary directories if they don't exist
directories_to_create = [
    "data/processed",
    "models",
    "results/predictions",
    "results/visualizations",
    "results/metrics",
    "logs",
    "outputs"
]

for directory in directories_to_create:
    Path(directory).mkdir(parents=True, exist_ok=True)
    print(f"✅ Created/verified directory: {directory}")

print("\n📁 All necessary directories created!")
# Out:
# ✅ Created/verified directory: data/processed
# ✅ Created/verified directory: models
# ✅ Created/verified directory: results/predictions
# ✅ Created/verified directory: results/visualizations
# ✅ Created/verified directory: results/metrics
# ✅ Created/verified directory: logs
# ✅ Created/verified directory: outputs
#
# 📁 All necessary directories created!

# %% [markdown]
# ## 7. Test CodeBERT Model Loading

# %%
# Test CodeBERT model and tokenizer loading
print("=" * 50)
print("TESTING CODEBERT MODEL LOADING")
print("=" * 50)

try:
    # Load CodeBERT tokenizer
    model_name = "microsoft/codebert-base"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    print(f"✅ CodeBERT tokenizer loaded: {model_name}")
    print(f"   Vocab size: {tokenizer.vocab_size}")
    print(f"   Max length: {tokenizer.model_max_length}")
    
    # Test tokenization with a simple code example
    test_code = """
    function transfer(address _to, uint256 _value) public {
        require(balances[msg.sender] >= _value);
        balances[msg.sender] -= _value;
        balances[_to] += _value;
    }
    """
    
    tokens = tokenizer(test_code, truncation=True, padding=True, return_tensors="pt")
    print(f"✅ Test tokenization successful")
    print(f"   Input shape: {tokens['input_ids'].shape}")
    print(f"   Sample tokens: {tokenizer.decode(tokens['input_ids'][0][:20])}...")
    
    # Load model (just for testing - we'll train our own)
    model = AutoModel.from_pretrained(model_name)
    model = model.to(device)
    print(f"✅ CodeBERT model loaded and moved to {device}")
    print(f"   Model parameters: {sum(p.numel() for p in model.parameters()):,}")
    
    # Clean up memory
    del model, tokenizer, tokens
    torch.cuda.empty_cache() if torch.cuda.is_available() else None
    
except Exception as e:
    print(f"❌ Error loading CodeBERT: {e}")
    print("   This might be due to network issues or missing dependencies")
# Out:
# ==================================================
# TESTING CODEBERT MODEL LOADING
# ==================================================
# ✅ CodeBERT tokenizer loaded: microsoft/codebert-base
#    Vocab size: 50265
#    Max length: 512
# ✅ Test tokenization successful
#    Input shape: torch.Size([1, 87])
#    Sample tokens: <s>
#     function transfer(address _to, uint256 _value) public {
# ...
# ✅ CodeBERT tokenizer loaded: microsoft/codebert-base
#    Vocab size: 50265
#    Max length: 512
# ✅ Test tokenization successful
#    Input shape: torch.Size([1, 87])
#    Sample tokens: <s>
#     function transfer(address _to, uint256 _value) public {
# ...
# ✅ CodeBERT model loaded and moved to cpu
#    Model parameters: 124,645,632
# ✅ CodeBERT model loaded and moved to cpu
#    Model parameters: 124,645,632

# %% [markdown]
# ## 8. Install and Test Slither

# %%
# Install Slither for static analysis
print("=" * 50)
print("INSTALLING SLITHER")
print("=" * 50)

try:
    # Install slither-analyzer
    # !pip install slither-analyzer
    print("✅ Slither installed successfully")
    
    # Test slither installation
    result = subprocess.run(['slither', '--version'], capture_output=True, text=True)
    if result.returncode == 0:
        print(f"✅ Slither version: {result.stdout.strip()}")
    else:
        print(f"⚠️  Slither version check failed: {result.stderr}")
        
except Exception as e:
    print(f"❌ Error installing Slither: {e}")
    print("   You may need to install it manually or check system requirements")

# %%
# Test Slither on a sample contract
sample_contract = """
pragma solidity ^0.8.0;

contract VulnerableContract {
    mapping(address => uint256) public balances;
    
    function transfer(address _to, uint256 _value) public {
        // Vulnerable to integer overflow (in older Solidity versions)
        balances[msg.sender] -= _value;
        balances[_to] += _value;
    }
    
    function withdraw() public {
        uint256 amount = balances[msg.sender];
        // Vulnerable to reentrancy
        (bool success, ) = msg.sender.call{value: amount}("");
        require(success);
        balances[msg.sender] = 0;
    }
}
"""

# Save sample contract for testing
with open("test_contract.sol", "w") as f:
    f.write(sample_contract)

try:
    # Run Slither on sample contract
    result = subprocess.run(
        ['slither', 'test_contract.sol', '--json', '-'], 
        capture_output=True, text=True, timeout=30
    )
    
    if result.returncode == 0 and result.stdout:
        slither_output = json.loads(result.stdout)
        print(f"✅ Slither analysis completed")
        print(f"   Detectors found: {len(slither_output.get('results', {}).get('detectors', []))} issues")
    else:
        print(f"⚠️  Slither test failed: {result.stderr}")
        
except Exception as e:
    print(f"⚠️  Slither test error: {e}")

# Clean up
if os.path.exists("test_contract.sol"):
    os.remove("test_contract.sol")

# %% [markdown]
# ## 9. Install and Test Mythril

# %%
# Install Mythril for symbolic execution analysis
print("=" * 50)
print("INSTALLING MYTHRIL")
print("=" * 50)

try:
    # Install mythril
    # !pip install mythril
    print("✅ Mythril installed successfully")
    
    # Test mythril installation
    result = subprocess.run(['myth', 'version'], capture_output=True, text=True)
    if result.returncode == 0:
        print(f"✅ Mythril version: {result.stdout.strip()}")
    else:
        print(f"⚠️  Mythril version check failed: {result.stderr}")
        
except Exception as e:
    print(f"❌ Error installing Mythril: {e}")
    print("   Mythril requires additional system dependencies (solc, etc.)")

# %% [markdown]
# ## 10. Save System Information

# %%
# Collect and save system information for reproducibility
system_info = {
    "timestamp": datetime.now().isoformat(),
    "platform": platform.platform(),
    "python_version": sys.version,
    "working_directory": os.getcwd(),
    "cuda_available": torch.cuda.is_available(),
    "cuda_version": torch.version.cuda if torch.cuda.is_available() else None,
    "device_count": torch.cuda.device_count() if torch.cuda.is_available() else 0,
    "packages": {
        "torch": torch.__version__,
        "transformers": transformers.__version__,
        "pandas": pd.__version__,
        "numpy": np.__version__,
        "sklearn": sklearn.__version__,
    },
    "random_seed": SEED
}

if torch.cuda.is_available():
    system_info["gpu_info"] = [
        {
            "id": i,
            "name": torch.cuda.get_device_name(i),
            "memory_gb": torch.cuda.get_device_properties(i).total_memory / 1e9
        }
        for i in range(torch.cuda.device_count())
    ]

# Save system info
with open("outputs/system_info.json", "w") as f:
    json.dump(system_info, f, indent=2)

print("💾 System information saved to outputs/system_info.json")
print("\n" + json.dumps(system_info, indent=2))
# Out:
# 💾 System information saved to outputs/system_info.json
#
# {
#   "timestamp": "2025-11-10T22:54:41.134765",
#   "platform": "Linux-6.14.0-32-generic-x86_64-with-glibc2.39",
#   "python_version": "3.12.3 (main, Aug 14 2025, 17:47:21) [GCC 13.3.0]",
#   "working_directory": "/home/virtualvasu/Desktop/sem5/ml_project/smart-contract-vuln-detector/notebooks",
#   "cuda_available": false,
#   "cuda_version": null,
#   "device_count": 0,
#   "packages": {
#     "torch": "2.7.1+cu118",
#     "transformers": "4.57.1",
#     "pandas": "2.3.3",
#     "numpy": "2.3.4",
#     "sklearn": "1.7.2"
#   },
#   "random_seed": 42
# }

# %% [markdown]
# ## 11. Environment Setup Summary

# %%
print("=" * 60)
print("🎉 ENVIRONMENT SETUP COMPLETE!")
print("=" * 60)

summary = f"""
✅ Setup Status:
   • Python {sys.version.split()[0]} configured
   • PyTorch {torch.__version__} installed
   • Transformers {transformers.__version__} ready
   • Device: {device}
   • Random seed: {SEED}
   • CodeBERT model tested
   • Project directories created
   • System info saved

🚀 Ready for next steps:
   1. Data acquisition and overview (01_data_acquisition_and_overview.ipynb)
   2. Preprocessing and function extraction
   3. Tokenization and dataset creation
   4. Model training and evaluation

📁 Key directories:
   • notebooks/ - Jupyter notebooks
   • data/processed/ - Processed datasets
   • models/ - Trained model checkpoints
   • results/ - Evaluation results and visualizations
   • outputs/ - Generated outputs and logs
"""

print(summary)

# Save summary to file
with open("outputs/setup_summary.txt", "w") as f:
    f.write(summary)

print("\n💾 Setup summary saved to outputs/setup_summary.txt")
print("\n🎯 Environment is ready! You can now proceed to the next notebook.")
# Out:
# ============================================================
# 🎉 ENVIRONMENT SETUP COMPLETE!
# ============================================================
#
# ✅ Setup Status:
#    • Python 3.12.3 configured
#    • PyTorch 2.7.1+cu118 installed
#    • Transformers 4.57.1 ready
#    • Device: cpu
#    • Random seed: 42
#    • CodeBERT model tested
#    • Project directories created
#    • System info saved
#
# 🚀 Ready for next steps:
#    1. Data acquisition and overview (01_data_acquisition_and_overview.ipynb)
#    2. Preprocessing and function extraction
#    3. Tokenization and dataset creation
#    4. Model training and evaluation
#
# 📁 Key directories:
#    • notebooks/ - Jupyter notebooks
#    • data/processed/ - Processed datasets
#    • models/ - Trained model checkpoints
#    • results/ - Evaluation results and visualizations
#    • outputs/ - Generated outputs and logs
#
#
# 💾 Setup summary saved to outputs/setup_summary.txt
#
# 🎯 Environment is ready! You can now proceed to the next notebook.
